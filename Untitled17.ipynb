# %%
import pandas as pd
import numpy as np
df =pd.read_csv(r'C:\Users\binoy\OneDrive\Desktop\entri calss\assignment 2\Employee (1).csv')
print (df.head())
# Out:
#    Company   Age  Salary     Place Country  Gender
# 0      TCS  20.0     NaN   Chennai   India       0
# 1  Infosys  30.0     NaN    Mumbai   India       0
# 2      TCS  35.0  2300.0  Calcutta   India       0
# 3  Infosys  40.0  3000.0     Delhi   India       0
# 4      TCS  23.0  4000.0    Mumbai   India       0

# %%
print(f"Unique values in {column}: {df[column].nunique()}")
print(f"Unique values: {df[column].unique()}")
print(df.describe())
# Out:
# Unique values in Gender: 2
# Unique values: [0 1]
#              Age       Salary     Gender
# count  91.000000    91.000000  91.000000
# mean   30.461538  4861.219780   0.219780
# std    12.161239  2684.750826   0.416392
# min     0.000000  1089.000000   0.000000
# 25%    22.000000  3000.000000   0.000000
# 50%    33.000000  4034.000000   0.000000
# 75%    40.000000  8000.000000   0.000000
# max    54.000000  9876.000000   1.000000

# %%
# data analysis
filtered_df = df[(df['Age'] > 40) & (df['Salary'] < 5000)]

# Plot the chart with age and salary
import matplotlib.pyplot as plt
plt.scatter(filtered_df['Age'], filtered_df['Salary'])
plt.xlabel('Age')
plt.ylabel('Salary')
plt.show()

# Count the number of people from each place and represent it visually
place_counts = filtered_df['Place'].value_counts()
plt.bar(place_counts.index, place_counts.values)
plt.xlabel('Place')
plt.ylabel('Count')
plt.show()

# %%
#DATA ENCODING
from sklearn.preprocessing import OneHotEncoder
ohe = OneHotEncoder()
encoded_df = pd.get_dummies(df, columns=['Place', 'Job'])
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[22], line 2
#       1 #DATA ENCODING
# ----> 2 from sklearn.preprocessing import OneHotEncoder
#       3 ohe = OneHotEncoder()
#       4 encoded_df = pd.get_dummies(df, columns=['Place', 'Job'])
#
# ModuleNotFoundError: No module named 'sklearn'

# %%
#data Feature Scaling
from sklearn.preprocessing import StandardScaler, MinMaxScaler

scaler = StandardScaler()
scaled_df_std = scaler.fit_transform(encoded_df)

scaler = MinMaxScaler()
scaled_df_mm = scaler.fit_transform(encoded_df)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[23], line 3
#       1 #data Feature Scaling
#       2 # Perform scaling of the features using standardscaler and minmaxscaler
# ----> 3 from sklearn.preprocessing import StandardScaler, MinMaxScaler
#       5 scaler = StandardScaler()
#       6 scaled_df_std = scaler.fit_transform(encoded_df)
#
# ModuleNotFoundError: No module named 'sklearn'

# %%
#Data Cleaning
df.isnull().sum()  
df.dropna(inplace=True)  

# Remove duplicate rows
df.drop_duplicates(inplace=True)

# Find outliers
from scipy import stats
z_scores = np.abs(stats.zscore(df))
print(z_scores)

# Replace the value 0 in age as NaN
df['age'].replace(0, np.nan, inplace=True)

# Treat null values in all columns
df.fillna(df.mean(), inplace=True)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[35], line 10
#       8 # Find outliers
#       9 from scipy import stats
# ---> 10 z_scores = np.abs(stats.zscore(df))
#      11 print(z_scores)
#      13 # Replace the value 0 in age as NaN
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\scipy\stats\_stats_py.py:2992, in zscore(a, axis, ddof, nan_policy)
#    2910 def zscore(a, axis=0, ddof=0, nan_policy='propagate'):
#    2911     """
#    2912     Compute the z score.
#    2913
#    (...)
#    2990            [-0.91611681, -0.89090508,  1.4983032 ,  0.88731639, -0.5785977 ]])
#    2991     """
# -> 2992     return zmap(a, a, axis=axis, ddof=ddof, nan_policy=nan_policy)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\scipy\stats\_stats_py.py:3156, in zmap(scores, compare, axis, ddof, nan_policy)
# ...
